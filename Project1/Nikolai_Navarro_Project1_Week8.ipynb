# %% [markdown]
# <a href="https://colab.research.google.com/github/Nikolai-N484/Data201_NikolaiN/blob/main/Project1/Nikolai_Navarro_Project1_Week8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Data 201 Project 1**
# ## **Nikolai Navarro**
# ## Submission Date

# %% [markdown]
# ---
# ## **Introduction**
# Write 1-2 paragraphs including:
#
# - Dataset origin
# - Population of interest
# - Data collection method and limitations
# - Ethical or bias concerns
#
# This dataset was collected by Montgomery County via its Automated Crash Reporting System which includes reports from Maryland state police such as Montgomery County Police, Gaithersburg Police, Rockville Police, or the Maryland-National Capital Park Police. This dataset focuses on traffic collisions involving non-motorists which mean pedestrians and cyclists.
#
# The data provided is updated weekly and may include missing information due to mechanical or human error. Some information may also be missing because of onging investigations.
#
#
#
# **Citation**:\
# “Crash Reporting - Non-Motorists Data: Open Data Portal.” Crash Reporting - Non-Motorists Data | Open Data Portal, Montgomery County, 27 Mar. 2026, data.montgomerycountymd.gov/Public-Safety/Crash-Reporting-Non-Motorists-Data/n7fk-dce5/about_data.

# %% [markdown]
# ---
# ## **Dataset Structure**
# Use code to:
#
# - Show dataset size (rows and columns)
# - Describe what each row represents\
# Create a table:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("https://raw.githubusercontent.com/Nikolai-N484/Data201_NikolaiN/refs/heads/main/Crash_Reporting_-_Non-Motorists_Data_20260329.csv")

df.head()
# Out:
#   Report Number  Local Case Number Agency Name ACRS Report Type  \
# 0   MCP3280007Y          260012513  MONTGOMERY     Injury Crash
# 1   MCP3126007Y          260012218  MONTGOMERY     Injury Crash
# 2   MCP3126007Y          260012218  MONTGOMERY     Injury Crash
# 3   MCP3077002M          260012176  MONTGOMERY     Injury Crash
# 4   MCP30790088          260011936  MONTGOMERY     Injury Crash
#
#           Crash Date/Time    Route Type           Road Name  \
# 0  03/22/2026 07:30:00 PM  County Route          STEWART LA
# 1  03/20/2026 08:01:00 PM           NaN                 NaN
# 2  03/20/2026 08:01:00 PM           NaN                 NaN
# 3  03/20/2026 03:53:00 PM  County Route  FATHER HURLEY BLVD
# 4  03/19/2026 09:19:00 AM           NaN                 NaN
#
#                             Cross-Street Name  \
# 0  OLD COLUMBIA PIKE OLD COLUMBIA PIKE (SB/L)
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#                                 Off-Road Description Municipality  ...  \
# 0                                                NaN          NaN  ...
# 1  Parking Lot Way        MILESTONE SHOPPING CENT...          NaN  ...
# 2  Parking Lot Way        MILESTONE SHOPPING CENT...          NaN  ...
# 3                                                NaN          NaN  ...
# 4  Parking Aisle        PARKING LOT IN FRONT OF L...          NaN  ...
#
#   Pedestrian Type          Pedestrian Movement         Pedestrian Actions  \
# 0      Pedestrian  Cross/Enter at Intersection  None (No Improper Action)
# 1      Pedestrian  Cross/Enter at Intersection  None (No Improper Action)
# 2      Pedestrian  Cross/Enter at Intersection  None (No Improper Action)
# 3      Pedestrian  Cross/Enter at Intersection  None (No Improper Action)
# 4      Pedestrian                        Other  None (No Improper Action)
#
#              Pedestrian Location At Fault         Injury Severity  \
# 0  Intersection Marked Crosswalk       No         Possible Injury
# 1  Intersection Marked Crosswalk       No  Suspected Minor Injury
# 2  Intersection Marked Crosswalk       No      No Apparent Injury
# 3  Intersection Marked Crosswalk       No         Possible Injury
# 4                          Other       No         Possible Injury
#
#   Safety Equipment   Latitude  Longitude                         Location
# 0              NaN  39.046210 -76.986543      (39.04620981, -76.98654308)
# 1              NaN  39.199092 -77.247840       (39.1990915, -77.24783967)
# 2              NaN  39.199092 -77.247840       (39.1990915, -77.24783967)
# 3              NaN  39.191983 -77.272170      (39.19198337, -77.27216959)
# 4              NaN  39.179210 -77.260974      (39.17920958, -77.26097442)
#
# [5 rows x 29 columns]

# %%
columns= df.columns

shape= df.shape

print(columns)
print(shape)
# Out:
# Index(['Report Number', 'Local Case Number', 'Agency Name', 'ACRS Report Type',
#        'Crash Date/Time', 'Route Type', 'Road Name', 'Cross-Street Name',
#        'Off-Road Description', 'Municipality', 'Related Non-Motorist',
#        'Collision Type', 'Weather', 'Surface Condition', 'Light',
#        'Traffic Control', 'Driver Substance Abuse',
#        'Non-Motorist Substance Abuse', 'Person ID', 'Pedestrian Type',
#        'Pedestrian Movement', 'Pedestrian Actions', 'Pedestrian Location',
#        'At Fault', 'Injury Severity', 'Safety Equipment', 'Latitude',
#        'Longitude', 'Location'],
#       dtype='object')
# (7147, 29)

# %% [markdown]
# ---
# ## **Data Analyses**
# Include the following four analyses. Use full sentences and interpret results in context.
#
# ### a. Quantitative Variable (Descriptive)
# - State a research question
# - Explain why your data is appropriate
# - Use summary statistics and visualization
#
# Discuss:
#
# - Data cleaning or transformation
# - Measures of center and spread
# - Outliers
# - Shape of distribution (symmetric, skewed, etc.)

# %% [markdown]
# ### b. Categorical Variable (Descriptive)
# - State a research question
# - Use summary statistics and visualization
#
# Discuss:
#
# - Data cleaning or transformation
# - Definition of levels
# - Interpretation of results

# %% [markdown]
# ### c. Relationship Between Variables (Exploratory)
# - State a research question
# - Revise if needed during analysis
#
# Discuss:
#
# - Why you expect an association
# - Whether an association exists
# - Description of the relationship

# %% [markdown]
# ### d. Nonparametric Inference (Median)
# - Use a random sample (~10%)
# - Explain your method
#
# Discuss:
#
# - Results of the inference
# - Interpretation

# %% [markdown]
# ---
# ## **Conclusions / Recommendations**
# Summarize:
#
# - Key findings
# - Trends or associations
#
# Suggest:
#
# - Next steps for further analysis
#
# If nothing stands out, clearly state that.
